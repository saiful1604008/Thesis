# %% [markdown]
# <a href="https://colab.research.google.com/github/saiful1604008/Thesis/blob/main/Final_CNN_Model_(175%2C350)_(Seizure_Detection).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mounting Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import cv2 as cv
import os 
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

from keras.layers import Conv2D,MaxPooling2D,Dropout,Dense,Flatten
from keras.models import Sequential
from keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# # Loading the Dataset

# %%
data_dir = "/content/drive/MyDrive/EEG_Seizure_Dataset_Thesis/"
num_classes = 2

# %% [markdown]
# # Train Test Split

# %%
datagen = ImageDataGenerator(
    rescale = 1.0/255,
    validation_split = 0.25
)

train_gen = datagen.flow_from_directory(
    directory= data_dir,
    target_size = (175,350),
    batch_size = 30,
    color_mode = 'rgb',
    shuffle = True,
    subset = 'training',
    class_mode = 'binary'
)

valid_gen = datagen.flow_from_directory(
    directory= data_dir,
    target_size = (175,350),
    batch_size = 30,
    color_mode = 'rgb',
    shuffle = False,
    subset = 'validation',
    class_mode = 'binary'

)
# Out:
# Found 760 images belonging to 2 classes.
# Found 253 images belonging to 2 classes.

# %%
input_shape = train_gen.image_shape
input_shape
# Out:
# (175, 350, 3)

# %%
valid_gen.class_indices
# Out:
# {'Normal': 0, 'Seizure': 1}

# %% [markdown]
# # Building CNN Model

# %%
model = Sequential([
                    Conv2D(16,(6,6),
                            strides=2,
                            activation="relu",
                            padding='same',
                            input_shape=input_shape),
                    MaxPooling2D(pool_size = 2,strides=1),
                    Dropout(0.5),
                    Conv2D(32,(3,3),
                           strides=1,
                           padding="same",
                           activation="relu"),
                    MaxPooling2D(pool_size = 2,strides = 1),
                    Dropout(0.5),
                    Conv2D(64,(3,3),
                           strides=1,
                           padding="same",
                           activation="relu"),
                    MaxPooling2D(pool_size = 2,strides = 1),
                    Dropout(0.5),
                    
                    Flatten(),
                    Dense(256,activation = 'relu'),
                    Dropout(0.5),
                    Dense(2,activation = 'softmax')
                    
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 88, 175, 16)       1744
#
#  max_pooling2d (MaxPooling2D  (None, 87, 174, 16)      0
#  )
#
#  dropout (Dropout)           (None, 87, 174, 16)       0
#
#  conv2d_1 (Conv2D)           (None, 87, 174, 32)       4640
#
#  max_pooling2d_1 (MaxPooling  (None, 86, 173, 32)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 86, 173, 32)       0
#
#  conv2d_2 (Conv2D)           (None, 86, 173, 64)       18496
#
#  max_pooling2d_2 (MaxPooling  (None, 85, 172, 64)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 85, 172, 64)       0
#
#  flatten (Flatten)           (None, 935680)            0
#
#  dense (Dense)               (None, 256)               239534336
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 239,559,730
# Trainable params: 239,559,730
# Non-trainable params: 0
# _________________________________________________________________

# %%
callback_list = EarlyStopping(monitor = 'val_loss',
                              patience = 20,
                              restore_best_weights=True)

# %%
model.compile(loss = 'sparse_categorical_crossentropy',
              optimizer = Adam(learning_rate = 0.0005),
              metrics = ['accuracy'])

# %%
Epoch = 200
batchSize = 32

history = model.fit(train_gen,
                    batch_size = batchSize,
                    epochs=Epoch,
                    callbacks=[callback_list],
                    validation_data=valid_gen,
                    verbose = 1)
# Out:
# Epoch 1/200
# 26/26 [==============================] - 195s 7s/step - loss: 29.6835 - accuracy: 0.5276 - val_loss: 0.5957 - val_accuracy: 0.7273
# Epoch 2/200
# 26/26 [==============================] - 152s 6s/step - loss: 0.5339 - accuracy: 0.7750 - val_loss: 0.6051 - val_accuracy: 0.8775
# Epoch 3/200
# 26/26 [==============================] - 153s 6s/step - loss: 0.3597 - accuracy: 0.9066 - val_loss: 0.5051 - val_accuracy: 0.8656
# Epoch 4/200
# 26/26 [==============================] - 155s 6s/step - loss: 0.2671 - accuracy: 0.9211 - val_loss: 0.4865 - val_accuracy: 0.8735
# Epoch 5/200
# 26/26 [==============================] - 151s 6s/step - loss: 0.1973 - accuracy: 0.9158 - val_loss: 0.4853 - val_accuracy: 0.7273
# Epoch 6/200
# 26/26 [==============================] - 152s 6s/step - loss: 0.1992 - accuracy: 0.9184 - val_loss: 0.4700 - val_accuracy: 0.8261
# Epoch 7/200
# 26/26 [==============================] - 155s 6s/step - loss: 0.1393 - accuracy: 0.9461 - val_loss: 0.3909 - val_accuracy: 0.8498
# Epoch 8/200
# 26/26 [==============================] - 155s 6s/step - loss: 0.1401 - accuracy: 0.9408 - val_loss: 0.3778 - val_accuracy: 0.8538
# Epoch 9/200
# 26/26 [==============================] - 156s 6s/step - loss: 0.1171 - accuracy: 0.9500 - val_loss: 0.3902 - val_accuracy: 0.8538
# Epoch 10/200
# 26/26 [==============================] - 155s 6s/step - loss: 0.1109 - accuracy: 0.9539 - val_loss: 0.3309 - val_accuracy: 0.8775
# Epoch 11/200
# 26/26 [==============================] - 158s 6s/step - loss: 0.1288 - accuracy: 0.9539 - val_loss: 0.3876 - val_accuracy: 0.7945
# Epoch 12/200
# 26/26 [==============================] - 150s 6s/step - loss: 0.0791 - accuracy: 0.9671 - val_loss: 0.3380 - val_accuracy: 0.8458
# Epoch 13/200
# 26/26 [==============================] - 150s 6s/step - loss: 0.0758 - accuracy: 0.9697 - val_loss: 0.3204 - val_accuracy: 0.8617
# Epoch 14/200
# 26/26 [==============================] - 150s 6s/step - loss: 0.0756 - accuracy: 0.9724 - val_loss: 0.3454 - val_accuracy: 0.8340
# Epoch 15/200
# 26/26 [==============================] - 150s 6s/step - loss: 0.0618 - accuracy: 0.9803 - val_loss: 0.3712 - val_accuracy: 0.8142
# Epoch 16/200
# 26/26 [==============================] - 151s 6s/step - loss: 0.0697 - accuracy: 0.9737 - val_loss: 0.3012 - val_accuracy: 0.8696
# Epoch 17/200
# 26/26 [==============================] - 151s 6s/step - loss: 0.0644 - accuracy: 0.9737 - val_loss: 0.3647 - val_accuracy: 0.8221
# Epoch 18/200
# 26/26 [==============================] - 151s 6s/step - loss: 0.0585 - accuracy: 0.9789 - val_loss: 0.3700 - val_accuracy: 0.8182
# Epoch 19/200
# 26/26 [==============================] - 150s 6s/step - loss: 0.0373 - accuracy: 0.9868 - val_loss: 0.4003 - val_accuracy: 0.8103
# Epoch 20/200
# 26/26 [==============================] - 152s 6s/step - loss: 0.0456 - accuracy: 0.9842 - val_loss: 0.4971 - val_accuracy: 0.7747
# Epoch 21/200
# 26/26 [==============================] - 151s 6s/step - loss: 0.0462 - accuracy: 0.9829 - val_loss: 0.3517 - val_accuracy: 0.8261
# Epoch 22/200
# 26/26 [==============================] - 154s 6s/step - loss: 0.0349 - accuracy: 0.9855 - val_loss: 0.3870 - val_accuracy: 0.8103
# Epoch 23/200
# 26/26 [==============================] - 152s 6s/step - loss: 0.0394 - accuracy: 0.9829 - val_loss: 0.4478 - val_accuracy: 0.8024
# Epoch 24/200
# 26/26 [==============================] - 153s 6s/step - loss: 0.0244 - accuracy: 0.9921 - val_loss: 0.4514 - val_accuracy: 0.7945
# Epoch 25/200
# 26/26 [==============================] - 153s 6s/step - loss: 0.0334 - accuracy: 0.9868 - val_loss: 0.2244 - val_accuracy: 0.8972
# Epoch 26/200
# 26/26 [==============================] - 152s 6s/step - loss: 0.0311 - accuracy: 0.9895 - val_loss: 0.3778 - val_accuracy: 0.8261
# Epoch 27/200
# 26/26 [==============================] - 153s 6s/step - loss: 0.0252 - accuracy: 0.9921 - val_loss: 0.3683 - val_accuracy: 0.8221
# Epoch 28/200
# 26/26 [==============================] - 155s 6s/step - loss: 0.0170 - accuracy: 0.9947 - val_loss: 0.2110 - val_accuracy: 0.8972
# Epoch 29/200
# 26/26 [==============================] - 156s 6s/step - loss: 0.0203 - accuracy: 0.9947 - val_loss: 0.2745 - val_accuracy: 0.8814
# Epoch 30/200
# 26/26 [==============================] - 152s 6s/step - loss: 0.0213 - accuracy: 0.9921 - val_loss: 0.5121 - val_accuracy: 0.7866
# Epoch 31/200
# 26/26 [==============================] - 153s 6s/step - loss: 0.0355 - accuracy: 0.9908 - val_loss: 0.4044 - val_accuracy: 0.8300
# Epoch 32/200
# 26/26 [==============================] - 154s 6s/step - loss: 0.0254 - accuracy: 0.9882 - val_loss: 0.3578 - val_accuracy: 0.8458
# Epoch 33/200
# 26/26 [==============================] - 153s 6s/step - loss: 0.0234 - accuracy: 0.9961 - val_loss: 0.4037 - val_accuracy: 0.8182
# Epoch 34/200
# 26/26 [==============================] - 155s 6s/step - loss: 0.0160 - accuracy: 0.9961 - val_loss: 0.4695 - val_accuracy: 0.8063
# Epoch 35/200
# 26/26 [==============================] - 150s 6s/step - loss: 0.0098 - accuracy: 0.9987 - val_loss: 0.4691 - val_accuracy: 0.8024
# Epoch 36/200
# 26/26 [==============================] - 151s 6s/step - loss: 0.0101 - accuracy: 0.9974 - val_loss: 0.3417 - val_accuracy: 0.8577
# Epoch 37/200
# 26/26 [==============================] - 154s 6s/step - loss: 0.0122 - accuracy: 0.9947 - val_loss: 0.3757 - val_accuracy: 0.8340
# Epoch 38/200
# 26/26 [==============================] - 151s 6s/step - loss: 0.0091 - accuracy: 0.9987 - val_loss: 0.5289 - val_accuracy: 0.8103
# Epoch 39/200
# 26/26 [==============================] - 151s 6s/step - loss: 0.0071 - accuracy: 0.9987 - val_loss: 0.4250 - val_accuracy: 0.8300
# Epoch 40/200
# 26/26 [==============================] - 152s 6s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.3875 - val_accuracy: 0.8656
# Epoch 41/200
# 26/26 [==============================] - 152s 6s/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.3940 - val_accuracy: 0.8458
# Epoch 42/200
# 26/26 [==============================] - 152s 6s/step - loss: 0.0137 - accuracy: 0.9961 - val_loss: 0.5913 - val_accuracy: 0.7826
# Epoch 43/200
# 26/26 [==============================] - 150s 6s/step - loss: 0.0620 - accuracy: 0.9776 - val_loss: 0.4406 - val_accuracy: 0.8142
# Epoch 44/200
# 26/26 [==============================] - 152s 6s/step - loss: 0.0215 - accuracy: 0.9934 - val_loss: 0.2869 - val_accuracy: 0.8854
# Epoch 45/200
# 26/26 [==============================] - 148s 6s/step - loss: 0.0152 - accuracy: 0.9934 - val_loss: 0.3766 - val_accuracy: 0.8419
# Epoch 46/200
# 26/26 [==============================] - 150s 6s/step - loss: 0.0324 - accuracy: 0.9908 - val_loss: 0.4109 - val_accuracy: 0.8182
# Epoch 47/200
# 26/26 [==============================] - 149s 6s/step - loss: 0.0289 - accuracy: 0.9895 - val_loss: 0.3496 - val_accuracy: 0.8735
# Epoch 48/200
# 26/26 [==============================] - 149s 6s/step - loss: 0.0186 - accuracy: 0.9961 - val_loss: 0.3557 - val_accuracy: 0.8617

# %% [markdown]
# # Accuracy

# %%
a = model.evaluate(train_gen)
# Out:
# 26/26 [==============================] - 30s 1s/step - loss: 0.0547 - accuracy: 0.9987

# %%
b = model.evaluate(valid_gen)
# Out:
# 9/9 [==============================] - 9s 1s/step - loss: 0.2110 - accuracy: 0.8972

# %%
print ('Training Accuracy:', a[1] )
print ('Validation Accuracy:', b[1])
# Out:
# Training Accuracy: 0.9986842274665833
# Validation Accuracy: 0.8972331881523132

# %% [markdown]
# # Plot of Accuracy & Loss

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='validation_accuracy')
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Number of Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Classification Report & Confusion Matrix

# %%
from sklearn.metrics import classification_report, confusion_matrix

target_names = []

for key in train_gen.class_indices:
    target_names.append(key)


y_pred = model.predict_generator(valid_gen)
y_pred = np.argmax(y_pred, axis=1)
print('Confusion Matrix')
cm = confusion_matrix(valid_gen.classes, y_pred)

print (cm)

print('\n')

print('Classification Report')
print(classification_report(valid_gen.classes, y_pred, target_names=target_names))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   if __name__ == '__main__':
# Confusion Matrix
# [[108  19]
#  [  7 119]]
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.94      0.85      0.89       127
#      Seizure       0.86      0.94      0.90       126
#
#     accuracy                           0.90       253
#    macro avg       0.90      0.90      0.90       253
# weighted avg       0.90      0.90      0.90       253

# %%
group_percentages = ["{0:.2%}".format(value) for value in
                     cm.flatten()/np.sum(cm)]

group_counts = ["{0:0.0f}".format(value) for value in
                cm.flatten()]

labels = [f"{v1}\n{v2}" for v1, v2 in
          zip(group_counts,group_percentages)]
          
labels = np.asarray(labels).reshape(2,2)

ax = sns.heatmap(cm, fmt = '' ,annot=labels, cmap = 'Greens')
ax.set_title('Confusion Matrix\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('\nActual Values\n');

ax.xaxis.set_ticklabels(['Non-Seizure','Seizure'])
ax.yaxis.set_ticklabels(['Non-Seizure','Seizure'])

plt.show()

# %% [markdown]
# # Plot of ROC(Receiver Operating Characteristic) Curve

# %%
import sklearn.metrics as metrics
y_pred_keras = model.predict(valid_gen)
preds = y_pred_keras[:,1]
fpr_keras, tpr_keras, thresholds_keras = metrics.roc_curve(valid_gen.classes, preds)
roc_auc = metrics.auc(fpr_keras, tpr_keras)

plt.title('ROC Curve')
plt.plot(fpr_keras, tpr_keras, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.ylabel('True Positive Rate (TPR)')
plt.xlabel('False Positive Rate (FPR)')
plt.grid()
plt.show()

# %% [markdown]
# # Sample I/O Checking

# %%
from tensorflow.keras.preprocessing import image

# %%
import os
for dirname, _, filenames in os.walk('/content/drive/MyDrive/EEG_Seizure_Dataset_Thesis/'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
def predictImage(file_name):
    image1 = image.load_img(file_name,target_size=(175,350))
    plt.imshow(image1)
    Y = image.img_to_array(image1)
    X = np.expand_dims(Y,axis=0)
    value = model.predict(X)
    v = np.argmax(value)
    print(v)
    if v == 1: 
        plt.xlabel("Seizure",fontsize= 20)
    elif v == 0:
        
        plt.xlabel("Non-Seizure",fontsize= 20)

# %%
predictImage('/content/drive/MyDrive/EEG_Seizure_Dataset_Thesis/Seizure/394.PNG')
# Out:
# 1

# %%
predictImage('/content/drive/MyDrive/EEG_Seizure_Dataset_Thesis/Normal/351.PNG')
# Out:
# 0
